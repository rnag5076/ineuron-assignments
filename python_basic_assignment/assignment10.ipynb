# %%
#1. How do you distinguish between shutil.copy() and shutil.copytree()?

#Ans. shutil.copy() function is used to copy a single file wheras the shutil.copytree() will copy an entire 
#     folder with all of its contents

# %%
#2. What function is used to rename files??


#Ans. os.rename() can be used to rename a file and in shutil we can use shutil.move() function for renaming
#     as well as moving them.

# %%
#3. What is the difference between the delete functions in the send2trash and shutil modules?

#Ans. send2trash function as the name suggests will move a file or folder to the recycle bin, while shutil
#     functions will remove them permanently

# %%
#4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is equivalent to File objects’ open() method?

#Ans. inside the zipfile library we have ZipFile() function which is equivalent to the open() function. inside 
#     this function the first argument we pass is the filename and the second argument is the mode to open
#     the zip file like read,write or append.

# %%
#5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

#Ans. 

import os
import shutil

source="/home/graylyrapier/Documents"
extension=['.pdf','.jpg']
destination="/home/graylyrapier/Documents/new"
n=0
if (os.path.isdir(destination) == True):
        shutil.rmtree(destination)
for folder, sub, files in os.walk(source):

    if (os.path.isdir(destination) == False):
        os.mkdir(destination)
    for f in files:
        file,ext=os.path.splitext(f)
        if ext in extension:
            pth=folder+"/"+f
            print(pth)
            shutil.copy(pth, destination)
            n+=1
print("copied "+str(n)+ " files..")
# Out:
# /home/graylyrapier/Documents/Romil's Resume.pdf
# /home/graylyrapier/Documents/Romil vaccination.pdf
# /home/graylyrapier/Documents/Untitled Document.pdf
# /home/graylyrapier/Documents/My_Invoice_1 Jul 2021, 12_27_50_299856832088.pdf
# /home/graylyrapier/Documents/photos/2021-03-11-143042.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/Pictures/Instagram/IMG_20200711_113607_692.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/Pictures/Instagram/IMG_20201209_224210_147.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/Pictures/Instagram/20201209_224611.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/Pictures/Instagram/IMG_20200809_211028_954.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/Pictures/Instagram/IMG_20200907_200821_203.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/Pictures/Instagram/IMG_20201124_201251_932.jpg
# /home/graylyrapier/Documents/Untitled Folder/phone/DCIM/Restored/IMG-20200831-WA0000.jpg
# ...
